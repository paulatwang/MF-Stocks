# %% [markdown]
# ## Get top scoring articles within foundations

# %%
from pathlib import Path
import os

path = os.getcwd()
parent = str(Path(path).parent.absolute())

print('Current path:', path)
print('Parent path:', parent)
# Out:
# Current path: /home/pw/Projects/mfstocks/code_and_data/analysis
# Parent path: /home/pw/Projects/mfstocks/code_and_data

# %% [markdown]
# Read data

# %%
import pandas as pd

news = pd.read_csv(parent + '/prep_and_cleaning/processed_data/emfd_processed.csv')

# %% [markdown]
# Get product of moral sentiment and foundation probabilities

# %%
# 1. Z-transform mf-probability and mf-sentiment scores
from scipy import stats

def standardize(df):
    probabilities = ['care_p', 'fairness_p', 'loyalty_p', 'authority_p','sanctity_p']
    sentiments = ['care_sent', 'fairness_sent', 'loyalty_sent','authority_sent','sanctity_sent']
    
    for p in probabilities:
        df[p] = stats.zscore(df[p])
    for s in sentiments:
        df[s] = stats.zscore(df[s])
        
    return df

# %%
# 2. Multiply transformed mf-probability * mf-sentiment
def multiply(df):
    foundations = ['care','fairness','loyalty','authority','sanctity']

    for f in foundations:
        df[f+'_prod'] = df[f+'_p'] * df[f+'_sent']
        
    return df

# %%
# 3. Get product and vice-virtue columns 

import numpy as np

def vice_virtue(df):
    foundations = ['care','fairness','loyalty','authority','sanctity']
    
    return df

# %%
standardized_news = standardize(news)
multiplied_news = multiply(standardized_news)
processed_news = vice_virtue(multiplied_news)

# %%
def datetime_index(df, colname_str):
    dt = pd.to_datetime(df[colname_str], format='%Y-%m-%d %H:%M:%S%z',utc=True)
    df.index = df.set_index(dt).tz_convert('US/Eastern').index
    return df
processed_news_dt = datetime_index(processed_news, "datetime2")

# %%
subset = processed_news_dt["2020-02-20":"2020-04-07"]

# %% [markdown]
# Order the titles by their degree of representation within a foundation

# %%
foundation = "authority" # adjust variable for foundation
subset.sort_values(by=f"{foundation}_prod", 
                           ascending=True # True for violation of foundation, False for upholding of foundation
                          )[["datetime2","url","title",f"{foundation}_prod"]].head(300).title.tolist()
# Out:
# ['When could the coronavirus curve flatten in the U.S.?',
#  'When could the coronavirus curve flatten in the U.S.?',
#  "Dr. Gupta: A national lockdown was needed 'from the get-go'",
#  "Dr. Gupta: A national lockdown was needed 'from the get-go'",
#  'The Navy relieved the commander of the USS Theodore Roosevelt of his duties today',
#  'The Navy relieved the commander of the USS Theodore Roosevelt of his duties today',
#  'Senator skeptical of Trump response to coronavirus',
#  'Senator skeptical of Trump response to coronavirus',
#  'ShowBiz Minute: Cardoz, Tekashi 6ix9ine, Tony Awards',
#  'See some of the most compelling space images and discoveries',
#  "Prince George's crime report",
#  'A Colorado Synagogue Struggles To Make Sense Of A Violent White Supremacist Threat',
#  "Prince George's crime report",
#  'Man grabs sword, chases man who told him to turn down music',
#  "Prince George's crime report",
#  "Inside NYC's first responder response: 'The great unknown' has people concerned",
#  "Inside NYC's first responder response: 'The great unknown' has people concerned",
#  "Michael Moore: Trump calling coronavirus a 'hoax' is 'dangerous'",
#  "Michael Moore: Trump calling coronavirus a 'hoax' is 'dangerous'",
#  'ShowBiz Minute: Weinstein, Smollett, Domingo',
#  "Notre Dame's Critical State: A Visual Guide",
#  'Coronavirus Wreaks Havoc On The Global Shipping Industry',
#  'Weinstein sentenced to 23 years for sexual assaults',
#  'NPR National Poetry Month: Nikky Finney',
#  "Star Wars trumps coronavirus at Montana boy's adoption ceremony",
#  "Senator 'very optimistic' about stimulus deal",
#  "Senator 'very optimistic' about stimulus deal",
#  'Protesters rally after N. Carolina police shooting',
#  "Critics Say Mississippi's Cellphone Felony Offense Is Too Harsh",
#  'Jussie Smollett pleads not guilty to restored charges',
#  'Jussie Smollett back in court on new charges',
#  'One Group Whose Political Leanings May Be Changing: Indian Americans Who Are Hindu',
#  "Pacino and Lerman are Nazi 'Hunters' in new Amazon series",
#  'Coronavirus: Masked couple harassed in NYC subway platform',
#  'American, Delta, United urged to seat families together for free',
#  'A Year After Accusations, Justin Fairfax Plots Next Act: A Run For Governor',
#  'Jon Meacham: Americans voted for normalcy on Super Tuesday',
#  'Jon Meacham: Americans voted for normalcy on Super Tuesday',
#  'Daniel Craig, Mandy Moore, Ben Affleck highlight weekend',
#  'Chris Hayes: Despite what Trump says, the U.S is in a coronavirus outbreak',
#  'Chris Hayes: Despite what Trump says, the U.S is in a coronavirus outbreak',
#  'One Square Mile: Bronzeville, Chicago, Illinois Guide',
#  "MA Professor Nicholas Pirelli Charged With Raping Student Tried to Make Another His 'Personal Prostitute'",
#  "'Leaning Tower Of Dallas' Defies Wrecking Ball",
#  'In Africa, Fierce Enforcement of Coronavirus Lockdowns Is Stirring Resentment',
#  'Saudis Tried to Kidnap Me on U.S. Soil, Regime Critic Says',
#  'Harvey Weinstein convicted of two sex crimes, reactions from courtroom',
#  'Harvey Weinstein found guilty of 3rd degree rape, criminal sexual act, acquitted on other charges',
#  'Harvey Weinstein found guilty of 3rd degree rape, criminal sexual act, acquitted on other charges',
#  'Insufficient testing hampers US response to coronavirus',
#  'Insufficient testing hampers US response to coronavirus',
#  'Joe Morgenstern - The Daily Beast',
#  'A firsthand account of coronavirus',
#  'A firsthand account of coronavirus',
#  "Latest Attack on U.S. Forces in Iraq Could Drag it Back into Washington's Tussle With Iran",
#  'Biden reacts to his victory in Virginia',
#  'Biden reacts to his victory in Virginia',
#  "'Traditional Techniques' by Stephen Malkmus Review: An Established Indie Rocker Still Explores New Ground",
#  'Trump: Could be dealing with coronavirus outbreak through July, August',
#  'Trump: Could be dealing with coronavirus outbreak through July, August',
#  'Portland Stabbing: Man Convicted Of Murder, Hate Crimes In 2017 Attack',
#  'Man who opened fire on Bronx cops indicted - New York Daily News',
#  "Reporter Yamiche Alcindor reacts to Sunday's briefing",
#  "Reporter Yamiche Alcindor reacts to Sunday's briefing",
#  'Brawl erupts in Turkish parliament over conflict in Syria',
#  "Glenn Beck, Steve King Go Conspiracy Crazy Over DHS Official's Death",
#  'Miami Mayor On Living With COVID-19',
#  'Jessica Migala',
#  'All Stories by Katherine Kelaidis - The Atlantic',
#  "'I'm in panic mode': Wife of COVID-19 patient pleads for plasma donations",
#  "'I'm in panic mode': Wife of COVID-19 patient pleads for plasma donations",
#  'Animals who lose mobility get help from chiropractor',
#  'Coronavirus Updates: Trump Administration Evaluates Lifting Restrictions',
#  'Chile Capital Rocked By Violent Anti-government Rallies',
#  'New Zealand Mosque Shooter Changes Plea to Guilty',
#  'NYC coronavirus first responders sleeping in cars for fear of infecting loved ones',
#  'NYC coronavirus first responders sleeping in cars for fear of infecting loved ones',
#  'United States passes 100,000 coronavirus cases',
#  'United States passes 100,000 coronavirus cases',
#  'Police In New Delhi Accused Of Failing To Protect Muslims',
#  'Maoist Rebels Gun Down 17 Indian Police',
#  'This 1955 Thunderbird Has Seen Its Share of Showbiz Royalty',
#  "Courtroom 'heavy with emotion' as Harvey Weinstein sentenced to 23 years in prison",
#  "Courtroom 'heavy with emotion' as Harvey Weinstein sentenced to 23 years in prison",
#  "Courtroom 'heavy with emotion' as Harvey Weinstein sentenced to 23 years in prison",
#  "Cramer's lightning round: 'I like Square very much'",
#  'Bluff The Listener',
#  'Queens teacher charged with sexually abusing autistic girl, 9',
#  'Militants in Iraq Take Covert Approach to Anti-U.S. Campaign',
#  'Mayor Eric Garcetti: No one has a bigger heart than Joe Biden',
#  'Mayor Eric Garcetti: No one has a bigger heart than Joe Biden',
#  'Weinstein taken to jail in ambulance',
#  'Phoenix shooting: police officer killed, 2 injured',
#  'US Federal Reserve cuts rates to zero, launches $700 billion quantitative easing program',
#  'US Federal Reserve cuts rates to zero, launches $700 billion quantitative easing program',
#  'Michael Weiss - The Daily Beast',
#  'Afterlife : NPR',
#  'With Medical Equipment in Short Supply, 3-D Printing Steps Up in Coronavirus Crisis',
#  "Coronavirus: McDonald's moves to drive-thru only amid pandemic",
#  'Canada Police Begin to Dismantle Rail Blockade in Eastern Canada',
#  'Beluga whales watch penguin at Shedd Aquarium',
#  'Number of Louisiana virus cases spikes',
#  "The Coronavirus Doesn't Discriminate. U.S. Health Care May Be A Different Story",
#  'Germany Raises Police Presence After Racist Terrorist Attack',
#  'Man accused of killing U.S. journalist Daniel Pearl to stay in prison',
#  'Dow soars nearly 1200 points on gains in Boeing, United Technologies shares',
#  'Order Prevents Release of Prisoner Convicted of Murdering Wall Street Journal Reporter Daniel Pearl in Pakistan',
#  'Cherry blossom DC: Festival details, peak bloom amid coronavirus worry',
#  'Respiratory doc: Trump should have issued a national lockdown two months ago',
#  'Respiratory doc: Trump should have issued a national lockdown two months ago',
#  "Coronavirus threat postpones Coachella; Billie Eilish's tour begins",
#  'Neo-Nazis Are Charged With Threats Against Jews, Minorities, Journalists',
#  'All Stories by Nesima Aberra - The Atlantic',
#  'Fatal hit and run in Brooklyn - New York Daily News',
#  'Giving birth and holding funerals: Life and loss during a pandemic',
#  'Giving birth and holding funerals: Life and loss during a pandemic',
#  'Why Raw Milk Is More Dangerous And Costs More Than Pasteurized Milk',
#  'NYPD searches for Bronx bus perv - New York Daily News',
#  "Turkish Troop Losses Mount in Battle for Syria's Last Rebel Stronghold",
#  'Report: Explosion near US Embassy in Tunisia',
#  'Matthew Klam Reads "The Liver" | The New Yorker',
#  'Super Tuesday Preview',
#  "A 'legal reckoning' for Harvey Weinstein",
#  'All Stories by Thomas Kirsch - The Atlantic',
#  'Where does the U.S. response to coronavirus stand?',
#  'Dan Goldberg',
#  'An Acid Attack In Milwaukee',
#  'Chile Creates Commission To Reform Much-criticized Police',
#  'College Student Wonders: In Hardcore Kenya, Is COVID-19 Lockdown Needed?',
#  'Harvey Weinstein taken into custody, to be detained until March 11 sentencing',
#  'Harvey Weinstein taken into custody, to be detained until March 11 sentencing',
#  'Ex-inmate who escaped conviction in fatal riot back in jail',
#  "United Technologies, Boeing share losses contribute to Dow's 1000-point drop",
#  'Marine Corps Aims To Tackle Evolving Face Of White Supremacy',
#  'NYPD : Cops can make arrests to enforce coronavirus rules',
#  'Nature up close: Springtime in Yellowstone',
#  'In Some Countries, Coronavirus Has Sparked An Authoritarian Power Grab',
#  'Teen stabs Bronx man to death, cops say',
#  "Coronavirus: Trump says virus spreading isn't Asian Americans' fault",
#  'Man shoots self after wounding girlfriend, chased to Queens',
#  "Elisabeth Moss: 'Plenty more to be done' post Weinstein",
#  'Montgomery County crime report',
#  'Crash ends car chase of stolen hearse with body inside',
#  'Jihadist Ambush Kills At Least 70 Nigerian Soldiers',
#  'Turkish Soldiers Killed During An Air Attack In Syria',
#  'Public Health Professor Answers Listener Questions About The Coronavirus',
#  'All Stories by Souvankham Thammavongsa',
#  'Doctor set to appear on Hill over vaccine development',
#  'Doctor set to appear on Hill over vaccine development',
#  'CFOs Look to Boost Cash Holdings, Cut Costs Amid Coronavirus Outbreak',
#  'Live Coverage: 2020 Super Tuesday primaries',
#  'Morning Digest: New batch of polling suggests Democrats could flip the Senate',
#  'Cattle Call 2020: South Carolina supercharges Biden, but Bernie Sanders retains frontrunner status',
#  'After testing positive for coronavirus, Sen. Rand Paul lashes out at critics',
#  'Let them die: Foreign-flagged cruise lines have no business asking for a U.S. bailout now',
#  "Pelosi's new stimulus bill includes national mail voting. Dems must not pass any stimulus without it",
#  'Affordable chicken may be nice, but the poultry plants behind it are harming the environment',
#  'Coronavirus updates: More closures as Senate shuffles into possible action',
#  "Trump 'very excited' about possible cure for COVID-19 … but you shouldn't share that excitement yet",
#  'Mike Pence does little more than pass the buck to local officials on coronavirus plans',
#  "McConnell's second attempt to bully Democrats on $500 billion corporate slush fund fails",
#  'Recruiter fired after allegedly telling high schoolers to line up by hair texture and skin color',
#  'For the third time this month, an immigrant has died while in ICE custody',
#  'Xenophobia and racism against Asian Americans increases as rumors about the coronavirus spread fear',
#  'Coronavirus updates, the South Carolina debate, and more you might have missed',
#  'Preparing for COVID-19 as Italy and Iran become new epicenters for a world entering pandemic',
#  'USDA inspector general will probe $2 million Alaska grant that went in part to timber lobbyists',
#  'Women-led activist organizations unite in demanding that Democratic candidate select a woman VP',
#  'After gutting Bloomberg, Warren lands a blow against a Las Vegas billionaire in his own newspaper',
#  "I fear Sanders' campaign has taught a bunch of political newcomers misogyny is as righteous as ever",
#  "Coronavirus point man Mike Pence's schedule is filled with everything but coronavirus response",
#  "Court of Appeals rules Florida can't hold voting rights hostage for payment of fines",
#  "Rushing to 'Herd immunity' on coronavirus is an extraordinarily foolish suggestion, with no upside",
#  'Saturday snippets: Oglalas legalize pot; Va. going 100% clean; slave graves complicate plastics plan',
#  "#WheresMitch trends (again) as bipartisan House bill on coronavirus languishes in Senate's absence",
#  "Friday night owls. Meyerson: 'Biden as Eisenhower'",
#  'Coronavirus has Trump worried about crashing markets, not disease and death',
#  'Missouri Republicans mistakenly kick 60,000 kids off of Medicaid, resist reinstating them',
#  'Pete Buttigieg ending his bid for the Democratic presidential nomination',
#  'Daily Kos | JoeBiden',
#  'Warren debated (eviscerated?) Bloomberg the way she would debate Trump—and yes, it matters',
#  'Immigrants are less likely to seek coronavirus-related health care, advocates say',
#  "Watch Simon Says champ William Barr dance to another president's tune in '91 confirmation hearing",
#  'Joe Biden wins Massachusetts Democratic primary',
#  'Warren for VP would not be the wrong move',
#  'Cattle Call 2020: So much for Bloomberg, can anyone beat Sanders?',
#  'As COVID-19 spreads, Republicans want to talk about ... Ebola',
#  "The window to avoid a global pandemic is 'narrowing' as COVID-19 grows in Italy, South Korea, Iran",
#  "Warren's debate win, AOC on 'The View', and more you might have missed",
#  'Joe Biden wins Tennessee Democratic primary',
#  'Joe Biden wins Arkansas Democratic primary',
#  'Live Coverage: 2020 Super Tuesday primaries',
#  'Joe Biden wins Oklahoma Democratic primary',
#  'Bernie Sanders wins Colorado Democratic primary',
#  "Operation 'Crimson Contagion' shows how the White House flubbed a test run at handling coronavirus",
#  '2020 Illinois primaries—live results',
#  'That time congressional Republicans postponed recess to rush ... the deportation of DACA recipients',
#  'Spotlight on green news & views: Blue whale pop. rises; bailing out oil; mopping up dirty mines',
#  "Don't panic, dammit! This week's picks from the Daily Kos Community",
#  "Government Accountability Office report continues to expose Trump admin's family separation cruelty",
#  'COVID-19: United States breaks 5,000 cases, then 6,000 cases, and 100 deaths ... all in the same day',
#  'Coronavirus is a huge labor issue, this week in the war on workers',
#  'Elections become the latest sector of American life to be impacted by the coronavirus',
#  "'A cry for help': Cameroonian women allege medical neglect, discrimination in ICE detention",
#  'Georgia attorney general confirms Brian Kemp abused his power by baselessly accusing Dems of hacking',
#  "Republicans have spewed so much fear over fake crises that they can't recognize a real one",
#  'Live coverage: March 17, 2020 primaries',
#  'White nationalists looking to weaponize coronavirus pandemic, both literally and figuratively',
#  'Groups sue Trump admin for immediate release of parents and kids from migrant family jails',
#  'Spotlight on green news & views: Blue whale pop. rises; bailing out oil; mopping up dirty mines',
#  'Florida lawmakers pass restrictive abortion bill, requiring parental consent for people under 18',
#  'Daily Kos | CDC',
#  "Bloomberg's defense of redlining comes back to haunt him during live debate",
#  'Roger Stone sentenced to 40 months ... start your pardon timers now.',
#  'CDC reports potentially significant outbreak of COVID-19 as cases reported coast to coast',
#  "Trump's Google coronavirus website lie may be the ultimate in simply making sh#t up",
#  'Lessons to learn from the March primaries',
#  'State and local governments clamor for Trump to finally lead on coronavirus',
#  'Ohio attorney general calls abortions non-essential surgeries that can wait during COVID-19 pandemic',
#  'Happy 10th Birthday, Affordable Care Act, such as it is in the Trump pandemic',
#  'ICE is forcing attorneys to scramble for masks in order to see detained clients amid mass shortage',
#  'What would your dream Joe Biden cabinet look like?',
#  "Federal judge says AG Barr can't be trusted, orders DOJ to turn over unredacted Mueller report",
#  "I checked in on Andrew Yang. Here's what he had to say about COVID-19 and universal basic income",
#  "The debate should have been a lesson for Bloomberg, one he doesn't seem capable of learning",
#  "Moscow Mitch's shameless crocodile coronavirus tears over Kentucky campaign fall short",
#  'CNBC host Rick Santelli suggests killing millions now, because coronavirus is bad for business',
#  'First they cut the safety rules on oil rigs. Then they covered up objections to cutting the rules',
#  'The 2020 Tokyo Summer Olympics will be postponed indefinitely',
#  'Instead of ensuring elections can be held amid coronavirus, Kentucky GOP passes new voter ID bill',
#  'Care first, jail last: The fight to stop LA from using jails as mental health treatment centers',
#  "Natives and eco-activists begin duel with gov't attorneys over Trump shrinking national monuments",
#  'California asks federal government to let SNAP recipients buy groceries online during pandemic',
#  "Lawmaker calls vaccines 'witches brew' as Connecticut moves closer to ending religious exemptions",
#  'Nonprofit investigates Colorado jail policies after pregnant woman left bleeding, baby dies',
#  "'Stop testing NBA players': Police chief urges Trump officials to 'start' testing first responders",
#  "'I didn't do nothing to you': Man accused of hopping train cars cries before Chicago cop shoots him",
#  "A day after mocking self-distancing, Trump-supporting 'evangelical' leader closes Liberty University",
#  'Daily Kos | SocialDistancing',
#  'Coronavirus is a crisis for the most vulnerable. Can you help?',
#  'Daily Kos | RandPaul',
#  'For the first time since signing 2015 agreement, Iran has enough enriched Uranium for a nuclear bomb',
#  'Trump signs emergency coronavirus spending bill',
#  'First doses of experimental coronavirus vaccine administered in Seattle',
#  'White Christians are becoming more Republican. How worried should Democrats be?',
#  'Daily Kos | Populists',
#  "Georgia closes probe into Kemp's bogus claim of Democratic election hacking in 2018",
#  "Trump administration response to coronavirus 'a perfect storm of three separate failures'",
#  'Conservatives furious that CPAC has been giving VIPs, and only VIPs, personal coronavirus updates',
#  "Gov't reports economy created 273,000 new jobs in February. U3 steady at 3.5%; U6 rises to 7%",
#  'Senate Democrats have plan to cancel student loan payments during crisis, payoff $10K on every loan',
#  'Daily Kos | AltRight',
#  'Watch Texas Lt. Gov. tell Tucker that patriotic grandparents should be willing to die for capitalism',
#  "Schumer, Pelosi slam Trump's irresponsible COVID-19 response, demand additional funding",
#  "What happens to kids who'd go hungry without free school lunches if coronavirus closes schools?",
#  "Schumer: Investigate Trump's acting director of national intelligence as unregistered foreign agent",
#  "The House just passed a bill to fight the coronavirus. Where's Mitch McConnell's Senate? On vacation",
#  "'We're stuck at our job, we can't leave': New York doormen left behind in coronavirus pandemic",
#  'Republican wants China banned from Twitter for the exact thing Donald Trump is doing now',
#  'Hobby Lobby founder tells workers that God spoke to his wife and forgot to mention paid sick leave',
#  'Monday night owls: Nuclear industry uses viral outbreak to seek fat bailout it begged for last fall',
#  "Trump bodyguard's purge of insufficiently loyal federal workers gets assist from college senior",
#  "As the super-rich donate masks and supplies, don't forget big-picture structural issues",
#  'Start paying attention to these possible coronavirus symptoms you may not have heard about',
#  'New York to pay incarcerated laborers 65 cents an hour to make hand sanitizer to fight coronavirus',
#  'Warren leads Democrats in calling on private prisons to release coronavirus plans',
#  'Senate Republicans finally release their coronavirus plan: Let Pelosi handle it',
#  'Republicans are up to their old trick, sending out fundraising mailers in the guise of the census',
#  "Trump can't win in November without foreign help, everyone knows it, and it's eating him alive",
#  'Along with lower emissions, offshore U.S. wind industry could create 83,000 more jobs by 2030',
#  'Donald Trump is modeling behavior that is going to get thousands of Americans killed',
#  'How the Obama administration tried to save us from what Trump is doing right now',
#  'CPS took my kids. Low access to evidence-based addiction treatment keeps families like mine apart',
#  'The propaganda network: Hours after Trump changed his tune on the pandemic, Fox hosts followed',
#  "Virginia Democrats voted to adopt bipartisan redistricting reform for 2021. Here's how it would work",
#  'COVID-19 cases explode in South Korea and Iran, even as conditions in China slightly improve',
#  'Voting Rights Roundup: Coronavirus may disrupt elections. The U.S. must enact universal vote-by-mail',
#  'Advocates call for the release of a transgender woman sexually assaulted in Arizona ICE facility',
#  'Daily Kos | Media',
#  'Daily Kos | ElizabethWarren',
#  'Daily Kos | Community',
#  'If the United States is a week behind Italy … brace yourself for horror that still seems impossible',
#  "Tuesday night owls: Excerpts from the April edition of the Harper's index",
#  "Trump's failure to take aggressive action on viral outbreak much worse than simple neglect",
#  "Trump still isn't concerned about coronavirus. He's concerned about his ratings on coronavirus",
#  "Anti-Asian racism and violence are surging amid coronavirus fears. Here's how groups are responding",
#  '70% of voters support paid sick leave',
#  "Monday night owls: Women prove 'electability' by winning big at the state and local levels",
#  'How do voting and social distancing go together? Upcoming primary states are working on it',
#  'Progressive Marie Newman unseats anti-choice Rep. Dan Lipinski in Illinois Democratic primary',
#  "Was Elizabeth Warren your candidate? Don't despair, our time is coming (pinky swear)",
#  'Daily Kos | SuperTuesday',
#  'Daily Kos | Vote2020',
#  "Wednesday night owls: 'Letting the Pentagon Loose With Your Tax Dollars'",
#  'Daily Kos | Covid-19',
#  'Daily Kos | Elections',
#  'Daily Kos | 2020election',
#  'CDC blocked top FDA scientist dispatched to expedite coronavirus response at critical moment',
#  'Daily Kos | Democrats',
#  'Daily Kos | 2020']

# %%
foundation = "sanctity" # adjust variable for foundation
subset.sort_values(by=f"{foundation}_prod", 
                           ascending=False # True for violation of foundation, False for upholding of foundation
                          )[["datetime2","url","title",f"{foundation}_prod"]].head(300).title.tolist()
# Out:
# ['I Love These Women-Only Sex Orgies. But Where Are the Lesbians?',
#  'American, Delta, United urged to seat families together for free',
#  'Instagram Monologue Leads To An Unlikely Anthem For Uncertain Times',
#  'Listener Questions About Dating During A Time Of Social Distancing',
#  'Senator skeptical of Trump response to coronavirus',
#  'Senator skeptical of Trump response to coronavirus',
#  'Birdsong, blaring sirens: A pandemic in sound',
#  'Coronavirus Wreaks Havoc On The Global Shipping Industry',
#  '100-year-old celebrates leap year birthday for 25th time',
#  'BTS greeted by screaming fans in New York',
#  "How Netflix 'Love is Blind' stars kept their marriage secret",
#  "San Francisco shelter-in-place in effect: NBC News' Jacob Ward reports",
#  'A D.C. Distillery Switches From Rum To Hand Sanitizer',
#  'See some of the most compelling space images and discoveries',
#  'Ohio governor on efforts to slow spread of virus in his state',
#  'Ohio governor on efforts to slow spread of virus in his state',
#  'Announcing the launch of the 50 Over 50 list',
#  'Announcing the launch of the 50 Over 50 list',
#  'New Orleans celebrates end of Mardi Gras',
#  'Coronavirus: Steps to take while washing produce',
#  "Neil Diamond posts COVID-19 PSA version of 'Sweet Caroline'",
#  'Chuck Norris: Martial arts master turned movie star turns 80',
#  'Artificial intelligence can help find your next skincare routine',
#  'Elementary School Principal Bonds With Students During Haircuts',
#  'A Sex Ed Update For An Internet-Enabled Generation',
#  "Understanding the Mind of an Addict on What's Eating America",
#  'Leap Day Babies: Just How Good (Or Bad) Is It To Have A Birthday Every 4 Years?',
#  'More Guidance On How To Properly Wear Masks',
#  'Groceries installing barriers amid virus outbreak',
#  'Joe: Sanders, Trump were two big winners last night',
#  'Joe: Sanders, Trump were two big winners last night',
#  'Animals who lose mobility get help from chiropractor',
#  'A firsthand account of coronavirus',
#  'A firsthand account of coronavirus',
#  'Runner shares powerful message about body positivity',
#  'UN adopts 4 resolutions, voting by email because of COVID-19',
#  'Taylor Swift, LeBron James and other celebrities need to encourage people to flatten the coronavirus curve',
#  'Chairwoman of Congressional Black Caucus endorses Joe Biden',
#  'Coronavirus could threaten endangered great apes, scientists warn',
#  'Goldman Sachs Has a Point on Credit Recovery, But Be Very Careful',
#  'A low-wage worker turns to minimum-wage activism after a life in poverty',
#  "Biden calls for 'meticulous oversight' of virus aid package",
#  'Playing figures like Trump and Castro is a minefield',
#  'Virginia city addressing young teens in effort to slow crime',
#  'Inside the new Waldorf Astoria condos',
#  'For parents of children with disabilities, home-schooling is an especially difficult task',
#  'Crew offloaded from USS Roosevelt as virus spreads',
#  'Casey Taylor | WIRED',
#  'Bryn Nelson - The Daily Beast',
#  "As Solar Energy's Price Has Dropped, More Companies Get Onboard",
#  "'Queer Eye' Karamo Brown Plays 'Not My Job' On 'Wait Wait... Don't Tell Me!' : NPR",
#  "GOP governor 'not happy' with Trump's calls to open economy",
#  'Voice Of The Unknown Woman: Afghan Filmmaker Roya Sadat',
#  'Universal Health posts higher Q4 profit',
#  'ABOUT HALF OF RESPONDENTS TO NEVADA DEMOCRATIC CAUCUS ENTRANCE POLL ARE COLLEGE GRADUATES, HALF HAVE NO COLLEGE DEGREE GÇô EDISON RESEARCH POLL',
#  'GIF or JIF, which is it?',
#  "Rep. Kennedy: The current relief plan is 'completely divorced from reality'",
#  "Rep. Kennedy: The current relief plan is 'completely divorced from reality'",
#  "Critics Say Mississippi's Cellphone Felony Offense Is Too Harsh",
#  'Illinois silo demolition is oddly mesmerizing',
#  'Keeping health care workers, public safe amid coronavirus',
#  'Keeping health care workers, public safe amid coronavirus',
#  'Donald Trump stares down his first Twitter-immune nemesis',
#  'Donald Trump stares down his first Twitter-immune nemesis',
#  'Sole plane passenger Sheryl gets personal shoutout from flight crew',
#  "Ashley Parker: Advisers told Trump he 'will own what happens with the coronavirus'",
#  "Ashley Parker: Advisers told Trump he 'will own what happens with the coronavirus'",
#  "It Is Day 2 Of President Trump's Trip To India",
#  'Coronavirus: Family recreates trip to Disney after parks close',
#  "Trump's 'Maximum Pressure' on Iran Is Helping Coronavirus Ravage the Country",
#  'New U.S.-Mexico Border Restrictions Set To Take Effect Due To Coronavirus Threat',
#  'Women Who Popped the Question',
#  'All Stories by Gay Courter - The Atlantic',
#  'Scots Pine In Czech Republic Chosen 2020 European Tree Of The Year',
#  "Congresswoman discusses 'dire' conditions in Queens hospitals",
#  "Congresswoman discusses 'dire' conditions in Queens hospitals",
#  'Where does the U.S. response to coronavirus stand?',
#  "Working from home is awesome. Here's how to excel at it",
#  'Every chain restaurant offering free delivery right now because of the coronavirus',
#  'Jet streams, temperature swings and other weather events that can only happen in the spring',
#  '25 facts about food allergies',
#  '5.7 magnitude earthquake hits Salt Lake City',
#  'Tips to help you successfully work from home',
#  'Easy, tasty dishes you can make with whatever is in your pantry',
#  'Does ketchup belong on a hot dog? And other great food debates',
#  'The life and legacy of Albert Einstein',
#  'Virus redefines respecting personal space',
#  'Can coronavirus spread through delivery? And other COVID-19 food questions answered',
#  "Where it all began: Music festivals of the '60s and '70s",
#  'Easter egg decorating around the world',
#  'You need to work from home and the kids are out of school. What now?',
#  "Carrie Underwood's hottest moments",
#  "Broccoli is a flower and other common foods that aren't what you think they are",
#  "Dwayne 'The Rock' Johnson, in a towel, sings handwash song to daughter",
#  'Americans fight to get home amid coronavirus lockdowns',
#  "Joe Biden to loved ones of coronavirus victims: 'My heart goes out to them'",
#  'Census Delays Field Operations Due To Coronavirus',
#  'Generations of Rosewood descendants keep a once-forgotten history alive',
#  'Atlanta residents who live above a hospital cheer medical workers',
#  'Atlanta residents who live above a hospital cheer medical workers',
#  'Pete Buttigieg: Bloomberg not what Dems believe in, opposed Obama and increases to minimum wage',
#  'Pete Buttigieg: Bloomberg not what Dems believe in, opposed Obama and increases to minimum wage',
#  'Trump tries to rewrite history after delayed coronavirus response',
#  'Trump tries to rewrite history after delayed coronavirus response',
#  'Bloomberg faces first ballot test on Super Tuesday',
#  'Bloomberg faces first ballot test on Super Tuesday',
#  "What to expect when you're expecting during a pandemic",
#  "What to expect when you're expecting during a pandemic",
#  'Coronavirus response of governors DeSantis, Kemp criticized',
#  'Killer Kitties? Scientists Track What Outdoor Cats Are Doing All Day',
#  'Golden Bag Chicken Dumplings With Thai Sweet Chile Sauce',
#  "Chris Hayes on Trump's failing response to coronavirus",
#  "Chris Hayes on Trump's failing response to coronavirus",
#  'Rachael Ray is helping families impacted by coronavirus',
#  "CHINA'S HUBEI PROVINCE, EPICENTRE OF CORONAVIRUS OUTBREAK, REPORTS 423 NEW CASES ON FEB 28 VS 318 ON FEB 27",
#  'Coronavirus: Tips for working parents at home with kids',
#  'Why Joe Biden now has to stay on his game',
#  'Why Joe Biden now has to stay on his game',
#  'What the 1918 influenza pandemic can teach us about coronavirus',
#  'What the 1918 influenza pandemic can teach us about coronavirus',
#  "Gov. Cuomo: Coronavirus pandemic is 'a full blown, nationwide crisis'",
#  "Gov. Cuomo: Coronavirus pandemic is 'a full blown, nationwide crisis'",
#  'Coronavirus: Bruce Willis, Demi Moore quarantine together with family',
#  'Should you wear a mask to protect from the coronavirus?',
#  'Should you wear a mask to protect from the coronavirus?',
#  'All Stories by E.J. Dionne Jr. - The Atlantic',
#  "'COVID Tech Connect' uses smart devices to connect coronavirus patients with family",
#  "'COVID Tech Connect' uses smart devices to connect coronavirus patients with family",
#  "Dr. Vin Gupta: Here in Seattle, 'strict measures have worked'",
#  "30 Empowering Quotes for Women's History Month",
#  'Rep. Meadows Will Soon Be The Official White House Chief Of Staff',
#  "Pot Heads: We're plants. We're stuck inside. We're making it work",
#  'Virus expert explains how to protect yourself from coronavirus',
#  'Virus expert explains how to protect yourself from coronavirus',
#  "Cynthia Greenlee's Profile",
#  'Goodyear stores to remain open Monday through Saturday',
#  "Peter Alexander on being called 'terrible reporter': I was pitching the president a 'softball' question",
#  "Peter Alexander on being called 'terrible reporter': I was pitching the president a 'softball' question",
#  'Too Much Hand-Washing? Here Are the Best Moisturizers',
#  'Ohio judge denies request to delay primary',
#  'Ohio judge denies request to delay primary',
#  "'Onward' Review: Where Did the Magic Go?",
#  'Nick Hanauer: How Do We Begin To Reinvent Capitalism?',
#  "Church services moving online 'the best thing' Rep. Demings says",
#  "Church services moving online 'the best thing' Rep. Demings says",
#  'Captain of aircraft carrier begs Navy for help as 93 sailors test positive for COVID-19',
#  'Captain of aircraft carrier begs Navy for help as 93 sailors test positive for COVID-19',
#  'Crane collapses outside under-construction stadium',
#  'What Hopi And Navajo Teachings Tell Us About Pandemics',
#  "A Thank-You Letter for Mrs. T's Two New Lungs",
#  'NBA star Karl-Anthony Towns says mother is in a coma after battling coronavirus symptoms',
#  'Garth Brooks, Trisha Yearwood crash Facebook Live with concert',
#  'Pedestrian killed in Fairfax County hit-and-run, the police said.',
#  'Trump frustrated by how pandemic is defining his presidency: reporter',
#  'Trump frustrated by how pandemic is defining his presidency: reporter',
#  'North Korea Fires Two Missiles in Its First Weapons Test This Year',
#  'Lottery State-by-State',
#  'Coronavirus fact check: Did Bill Gates predict outbreak in 2015?',
#  'Coronavirus Precautions For Foster Youth',
#  'All Stories by Brian Gabriel - The Atlantic',
#  'Closing Of Coal Power Plants Means Debates On What To Do With The Water They Used',
#  'Britney Spears calls for wealth redistribution in Instagram post',
#  "'Rebel Cinderella' Review: Between Two Worlds",
#  'Coronavirus: Disney World, Disneyland, Universal Orlando Studios close',
#  'U.S. Ports Likely to See Slump in Cargo Volume From Coronavirus',
#  'Why Hand Washing, Needed To Thwart COVID-19, Is A Problem In Mexico',
#  'The Complicated Pursuit Of Perfect',
#  'Trump winning his war on U.S. institutions: The Atlantic',
#  'Trump winning his war on U.S. institutions: The Atlantic',
#  'Subscribe | The New Yorker',
#  "Don't Stop The Music: DJ Hosts 10-hour Instagram Dance Party",
#  'National Enquirer Alum Dylan Howard Reportedly Ousted by AMI',
#  'Schools And Businesses Grapple With How To Cope With Coronavirus',
#  'Diner owner cooks free hot meals for his community',
#  "'My First Apartment Was So Small That...'",
#  'Mike Pearl - The Daily Beast',
#  '10 ways to work out at home during the coronavirus quarantine',
#  'Lela Loren finds similarities between biology and acting',
#  'Sharia Washington honors Kobe Bryant and Gianna with tattoo',
#  'Italy coronavirus outbreak: Residents clear grocery shelves',
#  'During Brain Sugery In London, A Musician Plays Her Violin',
#  'Traffic at Walmart, Costco and Target falls for the first time in weeks as coronavirus stockpiling behavior shifts',
#  'Respiratory doc: Trump should have issued a national lockdown two months ago',
#  'Respiratory doc: Trump should have issued a national lockdown two months ago',
#  "Trump faces a coronavirus threat. Let's look back at his Ebola tweets.",
#  'Man hospitalized with serious injuries in Brooklyn car crash',
#  'March jobs report: Economy sheds 701,000 jobs, unemployment up to 4.4%',
#  'Republicans mail out fake census documents',
#  'Republicans mail out fake census documents',
#  'The Wall Street Journal & Breaking News, Business, Financial and Economic News, World News and Video',
#  'How the WH mishandled first 70 days of coronavirus crisis',
#  'How the WH mishandled first 70 days of coronavirus crisis',
#  'David R. Lurie - The Daily Beast',
#  'All Stories by Kurt Vonnegut - The Atlantic',
#  'Travel vs. Environmentalism? Millennials Try to Do Both',
#  'Coronavirus Derails Capitol Hill on Surveillance, Energy Policy',
#  "Facebook Will Pay You For Sharing Your Voice Recordings: Here's How You Can Earn",
#  "Tom Hanks 'Better' After Virus Quarantine Down Under",
#  'WaPo reporter: So much of the timeline was squandered',
#  'WaPo reporter: So much of the timeline was squandered',
#  'AP Top Stories March 4 A',
#  'Parker: Trump incredibly frustrated coronavirus has economy shut down',
#  'Ethiopia Blames Design, Training Problems in Boeing 737 MAX Crash',
#  'Markets tank on new virus economic concerns',
#  'All Stories by Charles Crabtree - The Atlantic',
#  'Roger Stone Sentenced To Over 3 Years In Prison',
#  'Famous NY eatery closes but vows to come back',
#  'Cleaning tips to avoid spreading coronavirus in your own kitchen',
#  'Hundreds of coronavirus self-test kits sitting in U.S. awaiting FDA approval',
#  'Hundreds of coronavirus self-test kits sitting in U.S. awaiting FDA approval',
#  'Are There Enough Skilled Medical Workers To Run Ventilators?',
#  'Navy expected to fire captain who raised alarm about virus outbreak',
#  "Will Warren's attacks on Bloomberg prove effective?",
#  "Will Warren's attacks on Bloomberg prove effective?",
#  "The South Is Trump's to Lose. It Might Come Down to Rural Turnout",
#  "Today's Logistics Report: Suppliers Seeking Direction; Shifting Assembly Lines; Air Cargo Fracas",
#  'China begins easing coronavirus restrictions',
#  'China begins easing coronavirus restrictions',
#  "How The Coronavirus Crisis Is Changing Bernie Sanders' Campaign Message",
#  "Reality of coronavirus will challenge Trump's habit of making things up",
#  "Reality of coronavirus will challenge Trump's habit of making things up",
#  "Rep. Brady stresses need to 'protect' seniors amid coronavirus outbreak",
#  "Rep. Brady stresses need to 'protect' seniors amid coronavirus outbreak",
#  'Stacey Abrams: We had to adapt census outreach amid coronavirus pandemic',
#  'Stacey Abrams: We had to adapt census outreach amid coronavirus pandemic',
#  'Former Egyptian President Hosni Mubarak has died aged 91',
#  'Former Egyptian President Hosni Mubarak has died aged 91',
#  "Diana Ross' 'Love Hangover' is #1 on Billboard nearly 45 years after first topping charts",
#  'Cop takes 8-year-old girl who lost her dad to father-daughter dance',
#  'AP Top Stories March 27 P',
#  'Dance legend Debbie Allen to teach free class on Instagram',
#  "The Nation's Ballot Measures Fall Victim To COVID-19 Pandemic",
#  'U.S. suffers deadliest day of coronavirus outbreak thus far',
#  'U.S. suffers deadliest day of coronavirus outbreak thus far',
#  'Coronavirus: Australian couple hilariously recreates cancelled cruise',
#  'Italians, Under Coronavirus Lockdown, Keep Their Spirits Up With Singing and Cooking',
#  "Heed Biden's Call for Bipartisan Civility",
#  'Let the Fed Administer an Antiviral Shot',
#  "Meet Jalaiah Harmon: 6 Fun Facts About The 'Renegade' Dance Creator",
#  "Andy Slavitt: slowing spread of coronavirus 'is in our hands'",
#  "Andy Slavitt: slowing spread of coronavirus 'is in our hands'",
#  "FDA 'looking at everything' to treat virus",
#  'Solar Power Grows, but Market Share Is Low',
#  'Rep. Denny Heck on Russian interference in the 2020 election',
#  'Rep. Denny Heck on Russian interference in the 2020 election',
#  "Laura Linney Tackles Morally Flexible Opportunism In 'Ozark'",
#  'A simpler alternative to a wealth tax - The Washington Post',
#  'Pence tries for calm as virus response coordinator',
#  'Markets rebound after worst day since financial crisis',
#  'Markets rebound after worst day since financial crisis',
#  'Why You Should Stop Using Excuses',
#  'Deserted Rome: A timelapse ride though the city',
#  'Hummus Fans, Be On The Lookout For 6,150 Pounds Of Missing Chickpeas',
#  "Dow Inc., American Express share gains lead Dow's 725-point surge",
#  'Trump will ride the center lane in fall election campaign',
#  'Rep. Ami Bera on possible Coronavirus case near his district',
#  'Rep. Ami Bera on possible Coronavirus case near his district',
#  'OTIS Stock Price | Otis Worldwide Corp. Stock Quote (U.S.: NYSE)',
#  'Joe Biden wins Arizona, NBC News projects',
#  'Joe Biden wins Arizona, NBC News projects',
#  'Planet Fitness delivers mixed Q4 results, shares fall',
#  'How to care for over-washed, over-sanitized skin',
#  'Covid-19 Prepping Is a Boon to Kraft Heinz and Other Packaged-Foods Stocks',
#  'Remains of a 90-million-year-old rainforest discovered beneath Antarctic ice, study says',
#  "NYC mayor: 'Torrent' of new coronavirus cases coming, military aid may be needed",
#  "NYC mayor: 'Torrent' of new coronavirus cases coming, military aid may be needed",
#  'Motorcyclist dies in 3-vehicle crash on Henry Hudson Parkway',
#  "'Suicide mission:' Medical professionals describe going to work in New York City",
#  "'Suicide mission:' Medical professionals describe going to work in New York City",
#  'Sen. Warren starts off measured, then turns to Bloomberg',
#  'Sen. Warren starts off measured, then turns to Bloomberg',
#  'Cruise ship passengers in Florida plead for help as virus spreads aboard',
#  'Cruise ship passengers in Florida plead for help as virus spreads aboard',
#  "Woman's plea for blood plasma for her husband with COVID-19",
#  "Woman's plea for blood plasma for her husband with COVID-19",
#  'Keep calm, practice health safety measures, says virologist',
#  'Keep calm, practice health safety measures, says virologist',
#  "Teen fatally shot in Prince George's County, police say",
#  'Grilled L.A. Kalbi',
#  'How COVID-19 Has Affected Medical Care For Non-Coronavirus Patients',
#  'Rucker: Trump worried about coronavirus harming economy before 2020 election',
#  'Ohio woman practices social distancing in T-Rex costume',
#  'Columbus airport adds new nonstop flight to West Coast destination',
#  "'It was incredible': Reporter discusses reuniting with son",
#  "'It was incredible': Reporter discusses reuniting with son",
#  'Thank God, American Churches Are Dying',
#  'All Stories by Oliver Munday - The Atlantic',
#  'Feeling lonely?',
#  'Lady Gaga: Her Vegas residency and now her album release postponed',
#  "SpiritSisters's Profile",
#  'As New York coronavirus cases rise, Cuomo orders entire non-essential workforce home',
#  'As New York coronavirus cases rise, Cuomo orders entire non-essential workforce home',
#  'Norwegian Cruise Line Cancels Asia Voyages Through September',
#  "Coronavirus fears tank markets but Trump says everything's under control",
#  "Coronavirus fears tank markets but Trump says everything's under control",
#  'Pope tests negative for coronavirus, Italy report says',
#  'Joe: It is critical Trump get his arms around this virus',
#  'Joe: It is critical Trump get his arms around this virus',
#  "Dow's 2,159-point fall led by losses for Dow Inc., American Express stocks",
#  'Limericks : NPR']
